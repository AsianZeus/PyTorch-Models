# %%
import torch
import torchvision.transforms as transforms
from torchvision.utils import save_image
from CustomDatasetBuilder import CatsAndDogsDataset
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /Users/ace/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# 100%|██████████| 44.7M/44.7M [00:08<00:00, 5.80MB/s]
# Cost at epoch 0 is 9.17765998840332
# Cost at epoch 1 is 3.997119188308716
# Cost at epoch 2 is 0.7084908485412598
# Cost at epoch 3 is 0.13500560820102692
# Cost at epoch 4 is 0.03670281544327736
# Cost at epoch 5 is 0.010119214653968811
# Cost at epoch 6 is 0.003696448402479291
# Cost at epoch 7 is 0.0017750434344634414
# Cost at epoch 8 is 0.0010403564665466547
# Cost at epoch 9 is 0.0006951205432415009
# Checking accuracy on Training Set
# Got 5 / 5 with accuracy 100.00
# Checking accuracy on Test Set
# Got 3 / 5 with accuracy 60.00

# %%
my_transforms = transforms.compose([
    transforms.ToPILImage(),
    transforms.Resize((256,256)),
    transforms.RandomCrop((224,224)),
    transforms.ColorJitter(brightness=0.5,contrast=0.3),
    transforms.RandomRotation(degrees=45),
    transforms.RandomHorizontalFlip(p=0.5,)
    transforms.RandomVerticalFlip(p=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.0,0.0,0.0],std=[1.0,1.0,1.0])
    ])
dataset = CatsAndDogsDataset(csv_file='cats_dogs.csv',root_dir='cats_dogs_resized',transform=my_transforms)
# Out:
#   File "<ipython-input-8-4feb33a2e45f>", line 8
#     transforms.RandomVerticalFlip(p=0.2),
#     ^
# SyntaxError: invalid syntax

# %%
img_num=0 
for _ in range(10):
    for img, label in dataset:
        print(img.shape)
        save_image(img,'img'+str(img_num)+'.png')
        img_num+=1
# Out:
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
